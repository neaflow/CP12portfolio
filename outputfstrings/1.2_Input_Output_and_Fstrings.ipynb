# %% [markdown]
# # 1.2 — Input/Output & f-strings
#
# So far every value in your programs has been typed directly into the code. Today your programs start listening: `input()` lets a person type something back, and f-strings are the clean way to weave that (or any variable) into a sentence.

# %% [markdown]
# ## The Idea
#
# `input("prompt")` pauses your program, shows the prompt, and waits for the player to type something and hit Enter. Whatever they type comes back as a **string** — always, even if they typed a number.
#
# ```python
# player_name = input("What's your name, adventurer? ")
# ```
#
# An **f-string** lets you drop variables straight into a sentence — put an `f` right before the opening quote, and wrap each variable in `{ }`:
#
# ```python
# print(f"Welcome, {player_name}!")
# ```
#
# If you need a number instead of text, wrap `input()` in `int()` or `float()` to convert it:
#
# ```python
# starting_gold = int(input("How much gold do you start with? "))
# ```

# %%
# A worked example — greeting Zara at the start of the adventure

player_name = input("What's your name, adventurer? ")
starting_gold = int(input("How much gold do you start with? "))

print(f"Welcome, {player_name}!")
print(f"You set out with {starting_gold} gold in your pocket.")

# %% [markdown]
# *Watch out for:* `input()` **always** hands back a string, even if the player types `100`. Try to add two un-converted inputs together and you'll get string concatenation (`"10" + "5"` gives `"105"`, not `15`) instead of addition — wrap numeric input in `int()` or `float()` the moment you read it.

# %% [markdown]
# ## Guided Practice 1
#
# Old Finn wants to know a bit about you before he joins your party. Run the cell as-is, then change the prompts or add a line of your own.

# %%
# Old Finn asks a few questions — change the prompts below and re-run

favorite_weapon = input("Old Finn asks: what's your weapon of choice? ")
print(f"Old Finn nods. \"A {favorite_weapon}? Good choice.\"")
pass
# Out:
# Old Finn nods. "A rrrrr? Good choice."

# %% [markdown]
# ## Guided Practice 2
#
# The monster blocking your path wants to know what it's dealing with. Fill in every `____` — one line reads input, the next uses it in an f-string.

# %%
# Replace every ____ with the right function name (input or int)

character_class = input("What's your class? ")        # fill in: the function that reads text
print(f"You face the monster as a {character_class}.")

health = int(input("What's your starting health? "))  # fill in: convert-to-number, then read-text
print(f"You enter battle with {health} health.")
# Out:
# You face the monster as a f.
# You enter battle with 3 health.

# %% [markdown]
# ## Independent Practice 1
#
# Zara just found a weapon. Ask the player to name it (`input()`), then ask how much damage it deals (convert to `int` or `float`). Print a sentence using an f-string that includes both.
#
# **Hint (only if stuck):** it's the same two-line pattern as the worked example — `input()` for the name, `int(input())` for the number, then one `print(f"...")` using both.

# %%
name = input("weppon name ")
health = int(input("health "))
print(f"weapon name {name} and health {health}")

# %% [markdown]
# ## Independent Practice 2
#
# No hint this time. Ask the player to describe the room Zara just entered (a short description as a string) and how many monsters are in it (a number). Print a two-line status update using f-strings — one line for the description, one for the monster count.

# %%
name = input("what room are we in ")
mcount = int(input("how many monsters "))
print(f"room name {name} and monster count {health}")

# %% [markdown]
# ## Want More? (Optional)
#
# Ask for the room description, the monster count, *and* Zara's current health, then print all three in a single f-string on one line, formatted like a status bar: `Room: <desc> | Monsters: <n> | Health: <hp>`

# %%
name = input("what room are we in ")
health = int(input("health "))
mcount = int(input("how many monsters "))
print(f"room name {name} and monster count {health} and health {health}")

# %% [markdown]
# ## Check Your Understanding
#
# In one sentence: why do you need `int()` around `input()` when you want a number, but not when you want text?

# %% [markdown]
# **Your answer:** *(double-click to edit this cell)* `int()` converts a string to an integer that python can work with in calculations
