# %% [markdown]
# # Project 1Y — Diverges
#
# This one's meant to feel meaningfully different from the adventure game, not just a fancier version of it. Pick **one** of the three options below.

# %% [markdown]
# ## Option 1 — Small Simulation
#
# Build a dice-based combat simulator: two fighters, each with a health total, take turns rolling a die (`random.randint(1, 6)`) to determine damage, until one reaches 0. Run the simulation and print a turn-by-turn log, then a final result.
#
# *New tool you'll need:* `import random` at the top of your notebook, then `random.randint(a, b)` gives a random whole number between `a` and `b`, inclusive.

# %% [markdown]
# ## Option 2 — Data-Driven Twist
#
# Separate your game's *data* from its *logic*. Build a dictionary of dictionaries describing several rooms — each room name mapping to its own dictionary of details (description, danger level, items present) — then write a loop that reads from that data structure to run the adventure, instead of hardcoding each room's text directly into your code.
#
# ```python
# rooms = {
#     "entrance": {"description": "A dusty stone archway.", "danger": 1, "item": "torch"},
#     "corridor": {"description": "A narrow, dripping hallway.", "danger": 3, "item": None},
# }
# ```

# %% [markdown]
# ## Option 3 — Light Class Use
#
# Write a `Character` class with an `__init__` method that sets up `name`, `health`, and at least one other attribute, plus at least one other method (e.g. `take_damage(self, amount)` or `describe(self)`). Create at least two `Character` objects and show them interacting (e.g. one attacking the other).

# %% [markdown]
# ## Requirements (whichever option you pick)
#
# 1. Clearly working code for your chosen option, with the specific requirements above met
# 2. A short markdown note (below) explaining *why* you picked this option
# 3. This should feel meaningfully different from a reskinned version of the Core game — lean into what makes your option distinct

# %% [markdown]
# **Why I picked this option:** *(double-click to edit this cell)*

# %%
# Build your chosen option here.

print("in seperate file dice.py in this directory")
# Out:
# in seperate file dice.py in this directory

# %% [markdown]
# ## Before You Commit
#
# Run your project top to bottom at least twice to confirm it works reliably — simulations especially should be re-run a few times, since randomness means one successful run doesn't guarantee the next one won't hit an edge case.

# %% [markdown]
# ## AI Collaboration Log
#
# If you used AI for any part of this project, log it here before you commit — same habit as your portfolio README:
#
# - What did you ask for?
# - What did you keep, and what did you change?
#
# *(If you didn't use AI this time, just write "Didn't use AI for this one.")*
#
# **Your log:** *(double-click to edit this cell)*
