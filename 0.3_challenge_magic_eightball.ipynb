# %% [markdown]
# # Challenge: Build a Magic 8-Ball
#
# You've done this before — this is a quick warm-up to knock the rust off before we dive into Unit 1.
#
# **Before you start:** save this file into your cloned repo folder, then commit it in GitHub Desktop — that's your practice rep for today's local workflow. Come back and finish the challenge after.
#
# **About AI:** you're welcome to use it if you get stuck. But the point here is refreshing *your* fundamentals, not just producing working code — so:
# - Comment your code to explain what each part does, in your own words
# - Use proper syntax and formatting (consistent indentation, sensible variable names) even if AI wrote the first draft
# - I should be able to read your comments and follow your thinking, whether or not AI helped
#
# If you use AI, log it in your portfolio's AI Collaboration section like usual.

# %% [markdown]
# ## Level up
#
# **Tier 1 (required):** build the basic 8-ball:
# - Store at least **8 possible responses** (classic Magic 8-Ball answers, e.g. "Yes, definitely.", "Ask again later.", "Don't count on it.") in a list
# - Ask the user to type a yes/no question
# - Randomly pick one response and print it
#
# **From there, climb as far as you want:**
#
# 2. **Keep it going** — loop so the user can ask multiple questions in a row, until they type `quit`
# 3. **No repeats** — don't let the same response show up twice in a row
# 4. **Add a mood** — let the user pick a "mode" (e.g. nice / blunt / mysterious) that changes which set of responses gets used
# 5. **Add flair** — print a "thinking..." message with a short pause before the answer (look up `time.sleep()`), or count and report how many questions were asked by the end
# 6. **Open challenge** — already through all of that? Do something with this you haven't been taught here yet. Impress me.

# %% [markdown]
# ## What you'll need for Tier 1
#
# - A **list** to store your responses
# - The **`random`** module (specifically `random.choice()`) to pick one randomly
# - `input()` to get the user's question
# - `print()` to show the response
#
# Not sure how `random.choice()` works? That's worth looking up (or asking AI) — just make sure you understand and can explain it before you move on.
#
# Higher tiers will need tools we haven't named for you (loops, `time.sleep()`, maybe a dictionary) — looking those up yourself is part of the challenge.

# %%
import random

# your code here

# %% [markdown]
# ---
# ### Done?
#
# Commit this file again in GitHub Desktop — that's your second local commit for today. Then let me know you're finished, or keep going with a stretch goal.
